# %%
import json
ch_lop ='y'

while ch_lop=='y':

    print("\n***************************  Enter the choice  **********************************\n")
    print("\tAdmin : Press 1 \n\tUser : Press 2")
    ch_1=int(input("Enter your choice here : "))

    if ch_1 == 1:

        while ch_lop=='y':
            
            print("****************************  ADMIN  **************************************")
            print("\n\t 1. Display Stocks \n\t 2. Add Items \n\t 3. Remove Items \n\t 4. Sales Report\n\t 5. Exit ")
            ch_admin= int(input("Enter your choice :  "))

            if ch_admin<1 or ch_admin>5:
                print("\n\n*********************************************************************\n\t\t\t\t Please enter a valid choice \n***********************************************************************************************\n\n")
                
            else:
                
                    if ch_admin == 1:
                        print("\n***********************************************************************************************\n*************************************************  Display Stocks  ***********************************************\n")
                        fil_data = open('record.json','r')
                        temp=fil_data.read()
                        fil_data.close()

                        prod_dtl = json.loads(temp)

                        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
                        print("***********************************************************      PRODUCT LIST      **************************************************************")
                        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
                        print(" ")
                        print(f"{'  ' : <5}{'Product Id' : <14}{'Product Name' : >15}{'Company' : >25}{'Price' : >20}{'Category' : >15}{'Expiry_Date' : >25}{'Quantity' : >22}")
                        print(" ")

                        for i in prod_dtl:
                            print("------------------------------------------------------------------------------------------------------------------------------------------------")
                            print( '     ',i, end="           ") 
                            print(f"{prod_dtl[i]['product_name'] : <15}{prod_dtl[i]['company'] : >25}{prod_dtl[i]['price'] : >15}{prod_dtl[i]['category'] : >20}{prod_dtl[i]['expiry_date'] : >20}{prod_dtl[i]['quantity'] : >20}")
                        print("-------------------------------------------------------------------------------------------------------------------------------------------------")
    
    
                        print("")
                        print("*************************************************************************************************************************************************")
                        print("                                                                  ---xxx---                                                          ")
                            

                    elif ch_admin == 2:
        
                        print("*************************************************************************************************************\n************************************  Add Items  ****************************************\n")
                        fil_data = open('record.json','r')
                        temp = fil_data.read()
                        fil_data.close()
                        prod_dtl = json.loads(temp)

                        add_itm = 'y'
                        temp_dct = {}
                        while ch_lop=='y':
                            
                            prod_id = input("Enter the Product Id : ")
                            if (prod_id in prod_dtl.keys()):
                                print("The ITEM is already present in the list")
                                add_itm = input("Do you want to increase the Quantity of the produt.\nIf YES please enter 'y' otherwise press any key : ")
                                if add_itm == 'y':
                                    add_quantiy = int(input("Enter the quantity of the Product "))
                                    prod_dtl[prod_id]['quantity'] = prod_dtl[prod_id]['quantity'] + add_quantiy

                            else:
                                temp_dct['product_name'] = input("Enter the name of the PRODUCT : ")
                                temp_dct['company'] = input("Enter the name of the COMPANY : ")
                                temp_dct['price'] = int(input("Enter the PRICE of the PRODUCT : "))
                                temp_dct['category'] = input("Enter the CATEGORY of the PRODUCT : ")
                                temp_dct['expiry_date'] = input("Enter the EXPIRY DATE of the PRODUCT : ")
                                temp_dct['quantity'] = int(input("Enter the QUANTITY of the PRODUCT : "))
        
                                prod_dtl.update({prod_id:temp_dct})

                            print("Do you want to Add more Products ")
                            ch_lop = input("Enter 'y' if YES otherwise enter any key :  ")

                        updt_rec = json.dumps(prod_dtl)

                        nw_fil_data = open("record.json",'w')
                        nw_fil_data.write(updt_rec)
                        nw_fil_data.close()
                        ch_lop=input("Do you want to add more record.\nPress 'y' for YES and 'n' for NO : ")

                    elif ch_admin ==3:

                        print("*****************************************************************\n ************************************  Remove Items  *************************************\n")
                        fil_data = open('record.json','r')
                        temp = fil_data.read()
                        fil_data.close()
                        prod_dtl = json.loads(temp)
                        while ch_lop=='y':

                            prod_id = input("Enter the Product Id : ")
                            if (prod_id in prod_dtl.keys()):
                                del prod_dtl[prod_id]
                                print("Item deleted")
                            else:
                                print("Please enter a valid Product Id \nItem does not exist ")

                            print("Do you want to remove more Products ")
                            ch_lop = input("Enter 'y' if YES otherwise enter any key :  ")

                        updt_rec = json.dumps(prod_dtl)

                        nw_fil_data = open("record.json",'w')
                        nw_fil_data.write(updt_rec)
                        nw_fil_data.close()

                    elif ch_admin == 4:
                        print("*****************************************************************\n ************************************  Sales Report  *************************************\n")


                        fil_data = open('saless.json','r')
                        temp=fil_data.read()
                        fil_data.close()
                        prod_dtl = json.loads(temp)

                        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
                        print("***********************************************************      PRODUCT LIST      **************************************************************")
                        print("--------------------------------------------------------------------------------------------------------------------------------------------------")
                        print(" ")
                        print(f"{'  ' : <5}{'Product Id' : <14}{'Product Name' : >15}{'Company' : >28}{'Price' : >17}{'Category' : >15}{'Quantity' : >25}{'Total' : >20}")
                        print(" ")

                        for i in prod_dtl:
                            print("------------------------------------------------------------------------------------------------------------------------------------------------")
                            print( '     ',i, end="           ") 
                            print(f"{prod_dtl[i]['product_name'] : <15}{prod_dtl[i]['company'] : >25}{prod_dtl[i]['price'] : >15}{prod_dtl[i]['category'] : >20}{prod_dtl[i]['quantity'] : >20}{prod_dtl[i]['total'] : >20}")
                        print("-------------------------------------------------------------------------------------------------------------------------------------------------")
    
    
                        print("")
                        print("*************************************************************************************************************************************************")
                        print("                                                                  ---xxx---                                                          ")

                    elif ch_admin == 5 :
                        print("*****************************************************************\n ************************************  Exit  *********************************************\n")
                        print("\t\t\t\t***** THANK YOU *****")

                        ch_lop = 'n'
                        break
                        

                    ch_lop = input("\npress 'y' to continue or any key to exit : ")

                    if ch_lop != 'y':

                        print("\n***************************************************************************************************\n***********************************************  Exit  ********************************************************\n")
                        print("\t\t\t\t\t\t\t***** THANK YOU *****")
                        ch_lop = 'n'
                        break


    elif ch_1 == 2:

        while ch_lop == 'y':

            print("\n**********************************  USER  **************************************")
            print("\n\t 1. Display Items \n\t 2. Purchase Items \n\t 3. Exit ")
            ch_user= int(input("Enter your choice :  "))
            print(" ")

            if ch_user<1 or ch_user>4:
                print("\n\n***********************************************************************************************\n\t\t\t\t Please enter a valid choice \n***********************************************************************************************\n\n")
                
            else:
                
                    if ch_user == 1:
                        print("*****************************************************************************************\n************************************  Display Items  ************************************\n")
                        print("-----------------------------------------------------------------------------------------")
                        fil_data = open('record.json','r')
                        temp=fil_data.read()
                        fil_data.close()

                        prod_dtl = json.loads(temp)

                        print("-----------------------------------------------------------------------------------------")
                        print("******************************      PRODUCT LIST      ***********************************")
                        print("-----------------------------------------------------------------------------------------")
                        print(" ")
                        print(f"{'  ' : <5}{'Product Id' : <14}{'Product Name' : >15}{'Company' : >25}{'Price' : >20}")
                        print(" ")

                        for i in prod_dtl:
                            print("-------------------------------------------------------------------------------------")
                            print( '     ',i, end="           ") 
                            print(f"{prod_dtl[i]['product_name'] : <15}{prod_dtl[i]['company'] : >25}{prod_dtl[i]['price'] : >15}")
                        print("----------------------------------------------------------------------------------------")
    
    
                        print("")
                        print("****************************************************************************************")
                        print("                                      ---xxx---                                         ")


                    elif ch_user == 2:

                            print("*****************************************************************\n ************************************  Purchase Items  ****************************************\n")

                            ch_lop='y'

                            fil_data = open('record.json','r')
                            temp = fil_data.read()
                            fil_data.close()
                            prod_dtl = json.loads(temp)

                            sale_fil_data = open('saless.json','r')
                            temp_sale = sale_fil_data.read()
                            sale_fil_data.close()
                            sales_fil_rec = json.loads(temp_sale)


                            temp_dct = {}
                            sale_dtl = {}
                            total_bill = 0
                            while ch_lop=='y':
                                prod_id = input("Enter the Product Id : ")
                                if prod_id not in prod_dtl.keys():
                                    print("\t\t\t\t\t\t***  PRODUCT NOT FOUND *** \nP\t\t\t\t\t\tlease enter a valid Product Id ")

                                else:
                                    prod_quant = int(input("Enter the Quantity of the Product : "))

                                    price = prod_dtl[prod_id]['price']
                                    prod_name = prod_dtl[prod_id]['product_name']
                                    prod_comp = prod_dtl[prod_id]['company']
                                    prod_cat = prod_dtl[prod_id]['category']
                                    prod_bill = price*prod_quant
                                    total_bill = total_bill + prod_bill

                                    temp_dct['product_name'] = prod_name
                                    temp_dct['company'] = prod_comp
                                    temp_dct['price'] =  price
                                    temp_dct['category'] = prod_cat
                                    temp_dct['quantity'] = prod_quant
                                    temp_dct['total'] = prod_bill
        
                                    sale_dtl.update({prod_id:temp_dct})

                                    print("\n-------------------------------------------- ")
                                    print("******* Purchase Detail *********")
                                    print("--------------------------------------------- ")
                                    print("Product Name : ",prod_name)
                                    print("Category: ", prod_cat)
                                    print("Price : ", price)
                                    print("Quantity : ",prod_quant)
                                    print("Total Price : ",prod_bill)
                                    print(" ")
                                    print("***********************************************")
                                    print("-----------------------------------------------")

                                prod_dtl[prod_id]['quantity'] = prod_dtl[prod_id]['quantity'] - prod_quant

                                print("\nDo you want to Buy more Products ")
                                ch_lop = input("Enter 'y' if YES otherwise enter any key :  ")

                            print("\n----------------------------------------------------------------------------------------------------------------------")
                            print("**********************************************      BILL      *************************************")
                            print("------------------------------------------------------------------------------------------------------------------")
                            print(" ")
                            print(f"{'  ' : <5}{'Product Id' : <14}{'Product Name' : >15}{'Company' : >25}{'Price' : >20}{'Category' : >15}{'Quantity' : >22}{'TOTAL' : >15}")
                            print(" ")

                            for i in sale_dtl:
                                print("------------------------------------------------------------------------------------------------------------------------------------------------")
                                print( '     ',i, end="           ") 
                                print(f"{sale_dtl[i]['product_name'] : <15}{sale_dtl[i]['company'] : >24}{sale_dtl[i]['price'] : >16}{sale_dtl[i]['category'] : >21}{sale_dtl[i]['quantity'] : >14}{sale_dtl[i]['total'] : >20}")

                            print("\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tTOTAL BILL = ",total_bill)
                            print("-------------------------------------------------------------------------------------------------------------------------------------------------")
                            print("")

                            sales_fil_rec.update(sale_dtl)

                            updt_rec = json.dumps(prod_dtl)

                            nw_fil_data = open("record.json",'w')
                            nw_fil_data.write(updt_rec)
                            nw_fil_data.close()

                            sales_rec = json.dumps(sales_fil_rec)

                            nw_sale_fil_data = open("saless.json",'w')
                            nw_sale_fil_data.write(sales_rec)
                            nw_sale_fil_data.close()
                            ch_lop=input("Do you want to purchase more items.\nPress 'y' for YES and 'n' for NO : ")

                    elif ch_user == 3:
                        print("*****************************************************************\n ************************************  Exit  *************************************************\n")
                        print("\t\t\t\t***** THANK YOU *****")

                        ch_lop = 'n'
                        break


                    ch_lop = input("\npress 'y' to continue or any key to exit : ")

                    if ch_lop != 'y':

                        print("\n*****************************************************************************************\n************************************  Exit  *********************************************\n")
                        print("\t\t\t\t***** THANK YOU *****")
                        ch_lop = 'n'
                        break
# Out:
# ***************************  Enter the choice  **********************************
#
# 	Admin : Press 1
# 	User : Press 2
# Enter your choice here : 1
# ****************************  ADMIN  **************************************
#
# 	 1. Display Stocks
# 	 2. Add Items
# 	 3. Remove Items
# 	 4. Sales Report
# 	 5. Exit
# Enter your choice :  1
#
# ***********************************************************************************************
# *************************************************  Display Stocks  ***********************************************
#
# --------------------------------------------------------------------------------------------------------------------------------------------------
# ***********************************************************      PRODUCT LIST      **************************************************************
# ...
